# %% [markdown]
# classes and objects

# %% [markdown]
# object oriented programmimng (oop)is a programming paradigm that uses"objects"to design application and computer programs.oop allows for modeling real-world scenarios using classes and objects .tghis

# %%
## A class is a blue print for creating objects,attributes,methods


class car:
    pass

audi=car()
bmw=car()

print(type(audi))
# Out:
# <class '__main__.car'>

# %%
print(audi)
print(bmw) 

audi.windows=4
print(audi.windows)



##instance variables and methods
class dog:
    audi.windows=4
    print(audi.windows)
    
    tata=car()
    tata.doors=4
    
    print(tata.windows)
# Out:
# ...
# 4
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 10
#       5 print(audi.windows)
#       9 ##instance variables and methods
# ---> 10 class dog:
#      11     audi.windows=4
#      12     print(audi.windows)
#
# Cell In[15], line 17, in dog()
#      14 tata=car()
#      15 tata.doors=4
# ---> 17 print(tata.windows)
#
# AttributeError: 'car' object has no attribute 'windows'

# %%
dir(tata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 dir(tata)
#
# NameError: name 'tata' is not defined

# %%
##instance variables and methods
class dog:
    ##constructor
    
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
## create objects
dog1=dog('buddy',3)
print(dog1)  
print(dog1.name)
print(dog1.age)   


dog2=dog('luccy',3)
print(dog2)  
print(dog2.name)
print(dog2.age)
# Out:
# ...
# buddy
# 3
# ...
# buddy
# 3

# %%
##define a class with instance methods
class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
    def bark(self):
        print(f"{self.name} says woolf")  
        
dog1=Dog("buddy  ",3)
dog1.bark()
dog2=Dog("luccy",7)
dog2.bark()
# Out:
# biddy   says woolf
# luccy says woolf

# %%
##modelling a bank acocunt

##define a class for bank account
class bankaccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance
        
    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is depsoited.new balance is {self.balance}")
        
    def withdraw(self,amount):
        if amount>self.balance:
            print("insufficent funds")
            
        else:
            self.balance-=amount   
            
        print(f"{amount} is withdraw. new balnce is {self.balance}")
        
        
    def get_balance(self):
        return self.balance
    
    
    ##create an object
    
account=bankaccount("krish",500)
print(account.balance)

##     call instance methid
account.deposit(100)
# Out:
# 500
# 100 is depsoited.new balance is 600

# %%
account.withdraw(300)
# Out:
# 300 is withdraw. new balnce is 300

# %%
print(account.get_balance())
# Out:
# 300
