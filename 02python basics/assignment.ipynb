# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# 1. syntax and semantics

# %%
user_input=input("please enter something")
print("you entered:",user_input)
# Out:
# you entered: jyoti

# %%
number=float(input("Enter a number"))
if number >0:
    print("the number is positive")
elif number< 0:
    print("the number is negative")
else:
    print("the number is zero")
# Out:
# the number is zero

# %%
num1=float(input("enter the first numbers:"))
num2 =float(input("enter the second numbe:r"))
num3=float(input("enter the third number:"))
           
if (num1 >= num2) and (num1 >= num3):
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
      largest = num2
else:
  largest = num3
  
  
print("the largest number is:",largest)
# Out:
# the largest number is: 181.0

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
 
num=int(input("enter the number"))
print("the factorial number is", factorial(num))
# Out:
# the factorial number is 120

# %% [markdown]
# 2.varaibles and data types

# %% [markdown]
# Question 6; create variables of differnet data types: integers, floats,string and boolean print their values and types.

# %%
int_var = 10
float_var = 10.5
string_var = "hello"
bool_var = True

print(f"int value:{int_var}, type: {type(int_var)}")
print(f"float value:{float_var}, type: {type(float_var)}")
print(f"string value:{string_var}, type: {type(string_var)}")
print(f"bool value:{bool_var}, type: {type(bool_var)}")
# Out:
# int value:10, type: <class 'int'>
# float value:10.5, type: <class 'float'>
# string value:hello, type: <class 'str'>
# bool value:True, type: <class 'bool'>

# %% [markdown]
# Question 7: write a python program to swap the values of two variables

# %%
a=5
b=10
print(f"before swap:a={a},b={b}")

#swapping

a,b = b,a
print(f"After swap: a={a}, b={b}")
# Out:
# before swap:a=5,b=10
# After swap: a=10, b=5

# %% [markdown]
# Question 8. write a python program to convert celsius to fahrenheit

# %%
celsius = float(input("enter the temp in celsius:"))
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius}°C is equal to {fahrenheit}°F")
# Out:
# 15.0°C is equal to 59.0°F

# %% [markdown]
# Question 9. write a python program to concatenate two strings.

# %%
string1 = "hello"
string2 = "world"
concatenated_string = string1 + "" +string2
print("string is:", concatenated_string)
# Out:
# string is: helloworld

# %% [markdown]
# Question 10. write a python program to check if a variable is of a specific data type

# %%
var
