# %%
##Arithmetics opertions
a=10
b=5
add_result=a+b #addition
sub_result=a-b #subtraction
mul_result=a*b #multiplication
div_result=a/b #division
floor_div_result=a//b #floor division
modulus_result=a%b #modulus operators
exponent_result=a**b ## exponentaion
print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(floor_div_result)
print(modulus_result)
print(exponent_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
10/5
# Out:
# 2.0

# %%
21/5
# Out:
# 4.2

# %%
21//5
# Out:
# 4

# %% [markdown]
# comparison operators

# %%
##comparison operators
## ==
a=10
b=10
a==b
# Out:
# True

# %%
str1="jyoti"
str2="kumari"
str1==str2
# Out:
# False

# %%
#not equal to
str1!=str2
# Out:
# True

# %%
st3="jyoti"
str4="kumari"
str1!=str2
# Out:
# True

# %%
#greater than >
num1=45
num2=55
num1>num2
# Out:
# False

# %%
#less than <
num1=45
num2=55
num1<num2
# Out:
# True

# %%
#gretaer than equal to
num1=45
num2=45
num1>=num2
# Out:
# True

# %%
#less than equal to
num1=45
num2=45
num1<=num2
# Out:
# True

# %% [markdown]
# Logical operators

# %%
##and,not,or
x=True
y=True
result=(x and y)
print(result)
# Out:
# True

# %%
x=True
y=False
result=(x and y)
print(result)
# Out:
# False

# %%
#not operator
x=False
not x
# Out:
# True
