# %% [markdown]
# variables are fundamental elements in programming used to store data  that can be referneced and manipulated in a program. in python variables are created when you assign to value a them,and they do not need explicit declaraition to resrve memory space. the declaration happens automatically when you assign a value to a variable

# %%
a=100

# %%
##declaring and assigning variables
age=32
height=6.1
name="jyoti"
is_student=True

##printing thw variable
print("age :",age)
print("height:",height)
print("name:",name)
# Out:
# age : 32
# height: 6.1
# name: jyoti

# %%
#Naming convention
##variables anmes should be descriptive
#they must atart with a letter pr an'_' and contains letter,numbers and underscore
##varaible name are case sensitive


#valid avraible anme
first_name="jyoti"
last_name="kumari"

# %%
##understanding variables type
##python is dyna,ically typed of a variable is determined at runtime
age=25#int
height=6.1#float
name="jyoti"#string
is_student=True #bool

print(type(name))
# Out:
# <class 'str'>

# %%
#type checking and name conversion
type(height)
# Out:
# float

# %%
age=25
print(type(age))


#type conversion
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name="jyoti"
int(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 name="jyoti"
# ----> 2 int(name)
#
# ValueError: invalid literal for int() with base 10: 'jyoti'

# %%
height=6.0
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 6.0

# %%
##dynamic typing
##python allows the type of a variable to change as the program execute


var=10 #int
print(var,type(var)) 

var="hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
##input 

age=int(input("what is the age"))
print(age),type(age)
# Out:
# 23
# (None, int)

# %%
##simple calculator
num1 =float(input("enter the first number"))
num2= float(input("enter the second number"))
            
sum= num1+num2
differnce=num1-num2
product =num1 * num2
quotient=num1 /num2

print("sum",sum)
print("differnece:",differnce)
print("product",product)
print("quotient",quotient)
# Out:
# sum 25.0
# differnece: 5.0
# product 150.0
# quotient 1.5
