# %% [markdown]
# Data types are a classification of data of data which tell the compiler or interpreter how the programmer intends to use the data.
#
# they determine the type of operations that can be performed on the dat, the values that the data can take,and the amount of memory needed to store the data.

# %% [markdown]
# 2.Importance of data in programming
#
# ...Data types ensure the data is stored in an efficient way.
# ...They help in Performing correct operations on data.
# ...Proper use of Data types can prevent errors and bugs in the program.

# %%
##Integers Example
age=35
type(age)
# Out:
# int

# %%
##floating point data types
width=8.9
print(width)
print(type(width))
# Out:
# 8.9
# <class 'float'>

# %%
##string datatype example
name="jyoti"
print(name)
print(type(name))
# Out:
# jyoti
# <class 'str'>

# %%
## boolean data type
True
type(True)
# Out:
# bool

# %%
is_true=bool()
bool()
# Out:
# False

# %%
a=10
b=10
a==b
print(a==b)
type(a==b)
# Out:
# True
# bool

# %%
##commomn errors

result="hello" + str(5)
print(result)
# Out:
# hello5
