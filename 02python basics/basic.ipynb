# %% [markdown]
# syntax refers to the set of rules that defines the combination of symbols of symbols that are considered to be correctly structured programs in a language.in simple terms , syntax is about the correct arrangement of words and symbols in a code.
#
# semantics refer to the meaning or the interpretation of the symbols, characters, and command in a lanugage .in simple terms ,syntax is about the correct arrangement of words and symbols in a code.

# %%
## basic syntax rules in python
## case sensitivity -pyhton is case sensitive

name="krish"
Name="Naik"

print(name)
print(Name)
# Out:
# krish
# Naik

# %% [markdown]
# ###Indentation
#
# indetation in  python used to define the structure and hierarchy of the code.unlike many other programming language that use brace{} to delimit blocks of code ,python uses indentation to determine the grouping of statements.this means that all the statements within a block must be intendeted at the same level.

# %%
## INDentation
##python uses indentation to define  block of code. consistent use of spaces(commonly 4) or a tab is required.

age=32
if age>30:
    print(age)
print(age)
# Out:
# 32
# 32

# %%
## This is a single line comment
print("hello world")
# Out:
# hello world

# %%
## line continuation

total=1+2+3+4+5+6+7+\
4+5+6
print(total)
# Out:
# 43

# %%
##multiple statement on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## understand semantics in python
#varaible assignment
age=32 ## age is an integer
name="krish" #name is string

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
##Type inference
variable=10
print(type(variable))
variable="krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
    print(age)
# Out:
# 32

# %%
##name error
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined
