# %% [markdown]
# Importing Module in python:
#
#     In Python modules and packages help organizes and reuse code.her's a comprehensive guide on how to impot them.'

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import(sqrt,pi)
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *

print(sqrt(15))
print(pi)
# Out:
# 3.872983346207417
# 3.141592653589793

# %%
from package.maths import addition
addition(2,3)
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
from package.maths import addition
addition(2,3)
# Out:
# (2, 3)

# %%
from package.maths import substraction
substraction(4,3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from package.maths import substraction
#       2 substraction(4,3)
#
# ImportError: cannot import name 'substraction' from 'package.maths' (e:\udemy final\python\06importing creating modules\package\maths.py)
