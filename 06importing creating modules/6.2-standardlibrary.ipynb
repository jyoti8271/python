# %% [markdown]
# Standard Library Overview
#
#
# python's standard library is avast collection of modules and packkages that come bundled with python ,providing a wide range of functionalities out of the box.here's an overview of some of the most commomnly used modeules and packages in the python stanard library.

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(15))
print(math.pi)
# Out:
# 3.872983346207417
# 3.141592653589793

# %%
#random

import random
print(random.randint(1,10))
print(random.choice(['apple','cheery','banana']))
# Out:
# 7
# apple

# %%
## File and directory acess

import os
print(os.getcwd())
# Out:
# e:\udemy final\python\06importing creating modules

# %%
os.mkdir('test_dir')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 os.mkdir('test_dir')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'test_dir'

# %%
### High level operation on collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
### Data serialization

import json
data={'name':'krish','age':25}

json_str=json.dumps(data)
print(json_str)
print(type(json_str))


parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "krish", "age": 25}
# <class 'str'>
# {'name': 'krish', 'age': 25}
# <class 'dict'>

# %%
import csv
#write
with open('example.csv',mode='w',newline='')as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['krish',32])
    
#read

with open('example.csv',mode='r')as files:
    reader=csv.reader(files)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['krish', '32']

# %%
## datetime

from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2025-12-20 13:34:05.132680
# 2025-12-19 13:34:05.132680

# %%
# time

import time 
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1766217910.8642561
# 1766217912.8656318

# %%
### Regular expression

import re
pattern='\d+'
text='there are 123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123

# %% [markdown]
# Conclusion standard library is extensive and provides tools for almost any task you can think of from file handling to web services,from data serialization to concurrent execution .familirazing youself with the modules and packages availbale in the stamdad librabry can significantly enhance your abiltiy to write efficient and effective python program
