# %% [markdown]
# Examples..............................

# %% [markdown]
# 1...temperature conversion

# %%
def convert_temperature(temp,unit):
    """This functions convert temperature between celsius and farhenheite"""
    
    if unit=='C':
        return temp *9/5+32 ## celcius to farheinete
    
    elif unit=='f':
        return (temp-32)*5/9 ## Fahreheite to cesius
    
    else:
        return None
    
    
## calling the function
print(convert_temperature(77,'C'))
print(convert_temperature(40,'f'))
# Out:
# 170.6
# 4.444444444444445

# %% [markdown]
# 2....Password strength checker

# %%
def strong_password(password):
    """the function checks if the password is strong or not"""
    if len(password)<8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    
    if not any( char.islower()for char in password):
        return False
    
    if not any( char.isupper()for char in password):
        return False
    
    if not any( char in '!@#$%^&*()'for char in password):
        return False
    
    return True

## calling the function
print(strong_password("Jyoti123"))
print(strong_password("Jyoti@123"))
# Out:
# False
# True

# %% [markdown]
# 3...calculate the total cost of items in a shopping cart

# %%
def calculate_total_cost(cart):
    total_cost=0
    
    for items in cart:
        total_cost +=items['price']*items['quantity']
        return total_cost

##examples cart data
cart=[{'name':'apple','price':0.5,'quantity':4},
      {'name':'banana','price':0.3,'quantity':6},
      {'name':'orange','price':0.7,'quantity':3}]

##calling the function 
total_cost=calculate_total_cost(cart)
print("total cost is:",total_cost)
# Out:
# total cost is: 2.0

# %%
#check if a string is palindrome

def  is_palindrome(s):
     s=s.lower().replace(" ","")
     return s==s[::-1]

print("121",is_palindrome("121"))
print("hello",is_palindrome("hello"))
# Out:
# 121 True
# hello False

# %%
##calculate the  factorial of a number using recursion
